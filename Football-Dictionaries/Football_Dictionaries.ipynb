# %%
SQUADS_DATA = [
  [
    "1",
    "GK",
    "Juan Botasso",
    "(1908-10-23)23 October 1908 (aged 21)",
    "",
    "Quilmes",
    "Argentina",
    "Argentina",
    "1930"
  ],
  [
    "9",
    "FW",
    "Roberto Cherro",
    "(1907-02-23)23 February 1907 (aged 23)",
    "",
    "Boca Juniors",
    "Argentina",
    "Argentina",
    "1930"
  ],
  [
    "-",
    "MF",
    "Pierre Braine",
    "(1900-10-26)26 October 1900 (aged 29)",
    "42",
    "Royal Beerschot AC",
    "Belgium",
    "Belgium",
    "1930"
  ],
  [
    "-",
    "MF",
    "Alexis Chantraine",
    "(1901-03-16)16 March 1901 (aged 29)",
    "0",
    "Royal FC Liegeois",
    "Belgium",
    "Belgium",
    "1930"
  ],
  [
    "-",
    "GK",
    "Jean De Bie",
    "(1892-05-09)9 May 1892 (aged 38)",
    "37",
    "Royal Racing Club de Bruxelles",
    "Belgium",
    "Belgium",
    "1930"
  ],
  [
    "-",
    "MF",
    "Oscar",
    "(1991-09-09)9 September 1991 (aged 22)",
    "29",
    "Chelsea",
    "Brazil",
    "England",
    "2010"
  ],
  [
    "-",
    "MF",
    "Paulinho",
    "(1988-07-25)25 July 1988 (aged 25)",
    "25",
    "Tottenham Hotspur",
    "Brazil",
    "England",
    "2010"
  ],
  [
    "-",
    "MF",
    "Hernanes",
    "(1985-05-29)29 May 1985 (aged 29)",
    "23",
    "Internazionale",
    "Brazil",
    "Italy",
    "2014"
  ],
  [
    "-",
    "MF",
    "Luiz Gustavo",
    "(1987-07-23)23 July 1987 (aged 26)",
    "17",
    "VfL Wolfsburg",
    "Brazil",
    "Germany",
    "2014"
  ],
  [
    "-",
    "MF",
    "Fernandinho",
    "(1985-05-04)4 May 1985 (aged 29)",
    "6",
    "Manchester City",
    "Brazil",
    "England",
    "2014"
  ],
  [
    "-",
    "MF",
    "Willian",
    "(1988-08-09)9 August 1988 (aged 25)",
    "5",
    "Chelsea",
    "Brazil",
    "England",
    "2014"
  ],
  [
    "-",
    "FW",
    "Lee Keun-Ho",
    "(1985-04-11)11 April 1985 (aged 29)",
    "62",
    "Sangju Sangmu",
    "South Korea",
    "South Korea",
    "2014"
  ],
  [
    "-",
    "FW",
    "Koo Ja-Cheol",
    "(1989-02-27)27 February 1989 (aged 25)",
    "35",
    "Mainz 05",
    "South Korea",
    "Germany",
    "2014"
  ],
  [
    "-",
    "FW",
    "Kim Shin-Wook",
    "(1988-04-14)14 April 1988 (aged 26)",
    "26",
    "Ulsan Hyundai",
    "South Korea",
    "South Korea",
    "2014"
  ]
]

# %%
def players_as_dictionaries(a_list): 
    
    ''' 
    this function will take a list of lists as a parameter and will return a list of dict 
    the list structure is as follows:
    SQUADS_DATA = [
  [
    "1",                                     # Number
    "GK",                                    # Position
    "Juan Botasso",                          # Name
    "(1908-10-23)23 October 1908 (aged 21)", # Date of Birth
    "",                                      # Caps
    "Quilmes",                               # Club
    "Argentina",                             # Country (Players Country)
    "Argentina",                             # Club Country
    "1930"                                   # Year
  ],
    '''
    List_of_dict = []
    for player in a_list : 
        D = {
            'number' : player[0],
            'position' : player[1],
            'name' : player[2], 
            'date_of_birth' : player[3],
            'caps' : player[4],
            'club' : player[5],
            'country' : player[6], 
            'club_country' : player[7], 
            'year': player[8]
        }
        List_of_dict.append(D)
    return List_of_dict

# %%
def players_by_position(players): 
    new_D = {}
    for player in players : 
        position = player['position']
        if position in new_D: 
            new_D[position].append(player)
        else: 
            new_D[position] = [player]
    return new_D

# %%
def players_by_country_and_position(players): 
    players_country = {}
    for position,players in players.items(): 
        for player in players: 
            country = player['country']
            if country not in players_country : 
                players_country[country] = {}
            if position not in players_country[country]: 
                players_country[country][position] = []
            players_country[country][position].append(player)
    return players_country

# %%
SQUADS_DATA_as_dictionaries = players_as_dictionaries(SQUADS_DATA)

# %%
SQUADS_DATA_grouped_by_position = players_by_position(SQUADS_DATA_as_dictionaries)

# %%
SQUADS_DATA_grouped_by_position_and_country = players_by_country_and_position(SQUADS_DATA_grouped_by_position)

# %%
SQUADS_DATA_grouped_by_position_and_country
# Out:
# {'Argentina': {'GK': [{'number': '1',
#     'position': 'GK',
#     'name': 'Juan Botasso',
#     'date_of_birth': '(1908-10-23)23 October 1908 (aged 21)',
#     'caps': '',
#     'club': 'Quilmes',
#     'country': 'Argentina',
#     'club_country': 'Argentina',
#     'year': '1930'}],
#   'FW': [{'number': '9',
#     'position': 'FW',
#     'name': 'Roberto Cherro',
#     'date_of_birth': '(1907-02-23)23 February 1907 (aged 23)',
#     'caps': '',
#     'club': 'Boca Juniors',
#     'country': 'Argentina',
#     'club_country': 'Argentina',
#     'year': '1930'}]},
#  'Belgium': {'GK': [{'number': '-',
#     'position': 'GK',
#     'name': 'Jean De Bie',
#     'date_of_birth': '(1892-05-09)9 May 1892 (aged 38)',
#     'caps': '37',
#     'club': 'Royal Racing Club de Bruxelles',
#     'country': 'Belgium',
#     'club_country': 'Belgium',
#     'year': '1930'}],
#   'MF': [{'number': '-',
#     'position': 'MF',
#     'name': 'Pierre Braine',
#     'date_of_birth': '(1900-10-26)26 October 1900 (aged 29)',
#     'caps': '42',
#     'club': 'Royal Beerschot AC',
#     'country': 'Belgium',
#     'club_country': 'Belgium',
#     'year': '1930'},
#    {'number': '-',
#     'position': 'MF',
#     'name': 'Alexis Chantraine',
#     'date_of_birth': '(1901-03-16)16 March 1901 (aged 29)',
#     'caps': '0',
#     'club': 'Royal FC Liegeois',
#     'country': 'Belgium',
#     'club_country': 'Belgium',
#     'year': '1930'}]},
#  'South Korea': {'FW': [{'number': '-',
#     'position': 'FW',
#     'name': 'Lee Keun-Ho',
#     'date_of_birth': '(1985-04-11)11 April 1985 (aged 29)',
#     'caps': '62',
#     'club': 'Sangju Sangmu',
#     'country': 'South Korea',
#     'club_country': 'South Korea',
#     'year': '2014'},
#    {'number': '-',
#     'position': 'FW',
#     'name': 'Koo Ja-Cheol',
#     'date_of_birth': '(1989-02-27)27 February 1989 (aged 25)',
#     'caps': '35',
#     'club': 'Mainz 05',
#     'country': 'South Korea',
#     'club_country': 'Germany',
#     'year': '2014'},
#    {'number': '-',
#     'position': 'FW',
#     'name': 'Kim Shin-Wook',
#     'date_of_birth': '(1988-04-14)14 April 1988 (aged 26)',
#     'caps': '26',
#     'club': 'Ulsan Hyundai',
#     'country': 'South Korea',
#     'club_country': 'South Korea',
#     'year': '2014'}]},
#  'Brazil': {'MF': [{'number': '-',
#     'position': 'MF',
#     'name': 'Oscar',
#     'date_of_birth': '(1991-09-09)9 September 1991 (aged 22)',
#     'caps': '29',
#     'club': 'Chelsea',
#     'country': 'Brazil',
#     'club_country': 'England',
#     'year': '2010'},
#    {'number': '-',
#     'position': 'MF',
#     'name': 'Paulinho',
#     'date_of_birth': '(1988-07-25)25 July 1988 (aged 25)',
#     'caps': '25',
#     'club': 'Tottenham Hotspur',
#     'country': 'Brazil',
#     'club_country': 'England',
#     'year': '2010'},
#    {'number': '-',
#     'position': 'MF',
#     'name': 'Hernanes',
#     'date_of_birth': '(1985-05-29)29 May 1985 (aged 29)',
#     'caps': '23',
#     'club': 'Internazionale',
#     'country': 'Brazil',
#     'club_country': 'Italy',
#     'year': '2014'},
#    {'number': '-',
#     'position': 'MF',
#     'name': 'Luiz Gustavo',
#     'date_of_birth': '(1987-07-23)23 July 1987 (aged 26)',
#     'caps': '17',
#     'club': 'VfL Wolfsburg',
#     'country': 'Brazil',
#     'club_country': 'Germany',
#     'year': '2014'},
#    {'number': '-',
#     'position': 'MF',
#     'name': 'Fernandinho',
#     'date_of_birth': '(1985-05-04)4 May 1985 (aged 29)',
#     'caps': '6',
#     'club': 'Manchester City',
#     'country': 'Brazil',
#     'club_country': 'England',
#     'year': '2014'},
#    {'number': '-',
#     'position': 'MF',
#     'name': 'Willian',
#     'date_of_birth': '(1988-08-09)9 August 1988 (aged 25)',
#     'caps': '5',
#     'club': 'Chelsea',
#     'country': 'Brazil',
#     'club_country': 'England',
#     'year': '2014'}]}}
